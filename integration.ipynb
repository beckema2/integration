# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.set_theme(color_codes=True)

# %%
df = pd.read_csv('datenfinal.csv')
df
# Out:
#            land  einwohner_in_millionen entwicklung_einwohner_seit_2012  \
# 0       Belgien                   11.63                           4.33%
# 1   Deutschland                   83.24                           3.36%
# 2      Dänemark                    5.87                           4.74%
# 3      Finnland                    5.55                           2.36%
# 4    Frankreich                   67.84                           2.80%
# 5       Italien                   58.98                          -0.80%
# 6   Niederlande                   17.59                           4.65%
# 7      Norwegen                    5.46                           7.77%
# 8         Polen                   37.65                          -0.74%
# 9      Portugal                   10.35                          -2.05%
# 10     Schweden                   10.45                           9.42%
# 11      Schweiz                    8.74                           8.76%
# 12     Slowakei                    5.43                           0.74%
# 13      Spanien                   47.43                           1.18%
# 14   Tschechien                   10.52                           1.80%
# 15       Ungarn                    9.69                          -2.12%
# 16   Österreich                    8.98                           6.24%
#
#     flaeche_in_km2  einwohner_pro_km2  bip_je_einwohner_in_usd  \
# 0            30528                381                    51875
# 1           357376                233                    50795
# 2            42924                137                    67758
# 3           338440                 16                    54008
# 4           633187                107                    44853
# 5           302073                195                    35473
# 6            41540                423                    58292
# 7           385207                 14                    89090
# 8           312679                120                    17815
# 9            92226                112                    24264
# 10          438574                 24                    60029
# 11           41285                212                    93720
# 12           49035                111                    21053
# 13          505944                 94                    30090
# 14           78868                133                    26411
# 15           93011                104                    18968
# 16           83879                107                    53368
#
#    gesamtausgaben_bildung_prozentual_zum_bip  gesamtausgaben_bildung_pro_kopf  \
# 0                                      6.40%                             3320
# 1                                      5.00%                             2540
# 2                                      7.80%                             5285
# 3                                      6.30%                             3403
# 4                                      5.40%                             2422
# 5                                      4.30%                             1525
# 6                                      5.40%                             3148
# 7                                      7.60%                             6771
# 8                                      4.60%                              819
# 9                                      4.70%                             1140
# 10                                     7.60%                             4562
# 11                                     4.90%                             4592
# 12                                     4.00%                              842
# 13                                     4.20%                             1264
# 14                                     4.30%                             1136
# 15                                     4.60%                              873
# 16                                     5.20%                             2775
#
#     strassennetz_in_km   anzahl_registrierter_pkws_in_1000  \
# 0                  1763                               5889
# 1                 13192                              48249
# 2                  1354                               2724
# 3                   933                               3633
# 4                 11660                              38346
# 5                  6977                              39718
# 6                  2789                               8794
# 7                   580                               2935
# 8                  1712                              25114
# 9                  3065                               5566
# 10                 2179                               4943
# 11                 1544                               4658
# 12                  521                               2440
# 13                15722                              24717
# 14                 1298                               6049
# 15                 1774                               3921
# 16                 1749                               5092
#
#     neuzulassung_plug_in_hybride  neuzulassung_elektrofahrzeuge  \
# 0                          47761                        15044.0
# 1                         325449                       194163.0
# 2                          40478                        14218.0
# 3                          20139                         4245.0
# 4                         141001                       109597.0
# 5                          70472                        30930.0
# 6                          31016                        72858.0
# 7                          38166                        82212.0
# 8                           9269                         4619.0
# 9                          15660                            NaN
# 10                         77842                        27981.0
# 11                         21790                        19800.0
# 12                          1166                            NaN
# 13                         43226                        19186.0
# 14                          3907                            NaN
# 15                          4236                         3047.0
# 16                         14626                        15972.0
#
#     anzahl_ladestationen  ladestationen_pro_1000_einwohner_2020  \
# 0                  13695                                   0.71
# 1                  59410                                   0.53
# 2                   5752                                   0.51
# 3                   5497                                   0.60
# 4                  37128                                   0.67
# 5                  23543                                   0.22
# 6                  90284                                   3.53
# 7                   7689                                   3.40
# 8                   2811                                   0.02
# 9                   4124                                   0.20
# 10                 25197                                   0.92
# 11                  7200                                   0.85
# 12                  1367                                   0.11
# 13                 10480                                   0.16
# 14                  2189                                   0.09
# 15                  2541                                   0.10
# 16                 13110                                   0.91
#
#     ladestationen_pro_1000_einwohner_2021  pkw_pro_ladepunkt  \
# 0                                    1.15                518
# 1                                    0.77               1014
# 2                                    1.05                727
# 3                                    0.99                951
# 4                                    0.78                718
# 5                                    0.45               2273
# 6                                    4.81                109
# 7                                    4.50                147
# 8                                    0.08               7507
# 9                                    0.42               1596
# 10                                   2.01                353
# 11                                   1.20                575
# 12                                   0.32               1851
# 13                                   0.31               3118
# 14                                   0.25               4576
# 15                                   0.26               1813
# 16                                   1.92                594
#
#     pro_100km_autobahn  reifegrad_elektroinfrastruktur_2021  \
# 0                   50                                    5
# 1                   73                                    4
# 2                   59                                    4
# 3                  100                                    5
# 4                   48                                    5
# 5                   37                                    4
# 6                  106                                    9
# 7                  780                                    9
# 8                   58                                    2
# 9                   37                                    3
# 10                 125                                    4
# 11                 130                                    5
# 12                   3                                    4
# 13                  21                                    3
# 14                  94                                    3
# 15                  31                                    3
# 16                 115                                    6
#
#     reifegrad_elektroinfrastruktur_2022
# 0                                     6
# 1                                     3
# 2                                     5
# 3                                     6
# 4                                     4
# 5                                     3
# 6                                    10
# 7                                     8
# 8                                     3
# 9                                     2
# 10                                    7
# 11                                    7
# 12                                    4
# 13                                    3
# 14                                    5
# 15                                    4
# 16                                    8

# %%
sns.scatterplot(x="bip_je_einwohner_in_usd",y="entwicklung_einwohner_seit_2012", data=df)
plt.ylabel("Entwicklung Einwohner seit 2012")
plt.xlabel("BIP je Einwohner in USD")
plt.show()

# %%
sns.catplot(x="reifegrad_elektroinfrastruktur_2022", y="land", data=df)
plt.ylabel("Land")
plt.xlabel("Reifegrad Elektroinfrastruktur 2022")
# Out:
# Text(0.5, 8.95999999999998, 'Reifegrad Elektroinfrastruktur 2022')

# %%
sns.lmplot(x="reifegrad_elektroinfrastruktur_2022", y="einwohner_in_millionen", data=df)
plt.ylabel("Einwohner in Millionen")
plt.xlabel("Reifegrad Elektroinfrastruktur 2022")
var1 = df['reifegrad_elektroinfrastruktur_2022']
var2 = df['einwohner_in_millionen']
np.corrcoef(var1,var2)
# Out:
# array([[ 1.       , -0.5014365],
#        [-0.5014365,  1.       ]])

# %%
sns.regplot(x="einwohner_in_millionen", y="reifegrad_elektroinfrastruktur_2022", data=df);
plt.ylabel("Reifegrad Elektroinfrastruktur 2022")
plt.xlabel("Einwohner in Millionen")
# Out:
# Text(0.5, 0, 'Einwohner in Millionen')

# %%
sns.regplot(x="bip_je_einwohner_in_usd", y="reifegrad_elektroinfrastruktur_2022", data=df);
plt.ylabel("Reifegrad Elektroinfrastruktur 2022")
plt.xlabel("BIP pro Einwohner in USD")
var1 = df['reifegrad_elektroinfrastruktur_2022']
var2 = df['bip_je_einwohner_in_usd']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.68423674],
#        [0.68423674, 1.        ]])

# %%
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2021", data=df);
plt.ylabel("Anzahl Ladestationen pro 1000 Einwohner")
plt.xlabel("BIP pro Einwohner in USD")
var1 = df['ladestationen_pro_1000_einwohner_2021']
var2 = df['bip_je_einwohner_in_usd']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.64493187],
#        [0.64493187, 1.        ]])

# %%
sns.regplot(x="einwohner_pro_km2", y="ladestationen_pro_1000_einwohner_2021", data=df);
plt.ylabel("Anzahl Ladestationen pro 1000 Einwohner")
plt.xlabel("Anzahl Einwohner pro km2")
var1 = df['ladestationen_pro_1000_einwohner_2021']
var2 = df['einwohner_pro_km2']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.22806677],
#        [0.22806677, 1.        ]])

# %%
sns.regplot(x="gesamtausgaben_bildung_pro_kopf", y="ladestationen_pro_1000_einwohner_2021", data=df);
plt.ylabel("Anzahl Ladestationen pro 1000 Einwohner")
plt.xlabel("Gesamtausgaben für Bildung pro Kopf")
var1 = df['ladestationen_pro_1000_einwohner_2021']
var2 = df['gesamtausgaben_bildung_pro_kopf']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.67015303],
#        [0.67015303, 1.        ]])

# %%
SwissData = df[df['land']=='Schweiz']
SpainData = df[df['land']=='Spanien']
GermanData = df[df['land']=='Deutschland']
PortugueseData = df[df['land']=='Portugal']
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2021", data=SwissData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2020", data=SwissData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2021", data=SpainData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2020", data=SpainData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2021", data=GermanData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2020", data=GermanData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2021", data=PortugueseData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2020", data=PortugueseData)
plt.ylabel("Anzahl Ladestationen pro 1000 Einwohner")
plt.xlabel("BIP pro Einwohner in USD")
# Out:
# Text(0.5, 0, 'BIP pro Einwohner in USD')
