# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.set_theme(color_codes=True)

# %%
df = pd.read_csv('datenfinal.csv')
df
# Out:
#            land  einwohner_in_millionen  entwicklung_einwohner_seit_2012  \
# 0       Belgien                   11.63                            0.043
# 1   Deutschland                   83.24                            0.034
# 2      Dänemark                    5.87                            0.047
# 3      Finnland                    5.55                            0.024
# 4    Frankreich                   67.84                            0.028
# 5       Italien                   58.98                           -0.008
# 6   Niederlande                   17.59                            0.047
# 7      Norwegen                    5.46                            0.078
# 8         Polen                   37.65                           -0.007
# 9      Portugal                   10.35                           -0.021
# 10     Schweden                   10.45                            0.094
# 11      Schweiz                    8.74                            0.088
# ...

# %%
sns.catplot(x="reifegrad_elektroinfrastruktur_2022", y="land", data=df)
plt.ylabel("Land")
plt.xlabel("Reifegrad Elektroinfrastruktur 2022")
# Out:
# Text(0.5, 8.95999999999998, 'Reifegrad Elektroinfrastruktur 2022')

# %%
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2021", data=df);
plt.xlabel("BIP pro Einwohner")
plt.ylabel("Ladestationen pro 1000 Einwohner ")
var1 = df['bip_je_einwohner_in_usd']
var2 = df['ladestationen_pro_1000_einwohner_2021']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.64493187],
#        [0.64493187, 1.        ]])

# %%
sns.regplot(x="gesamtausgaben_bildung_pro_kopf", y="ladestationen_pro_1000_einwohner_2021", data=df);
plt.xlabel("Gesamtausgaben Bildung pro Kopf")
plt.ylabel("Ladestationen pro 1000 Einwohner ")
var1 = df['gesamtausgaben_bildung_pro_kopf']
var2 = df['ladestationen_pro_1000_einwohner_2021']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.67015303],
#        [0.67015303, 1.        ]])

# %%
sns.regplot(x="neuzulassung_elektrofahrzeuge", y="ladestationen_pro_1000_einwohner_2021", data=df);
plt.xlabel("Neuzulassung Elektrofahrzeuge")
plt.ylabel("Ladestationen pro 1000 Einwohner")
var1 = df['neuzulassung_elektrofahrzeuge']
var2 = df['ladestationen_pro_1000_einwohner_2021']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.30334743],
#        [0.30334743, 1.        ]])

# %%
sns.regplot(x="einwohner_in_millionen", y="ladestationen_pro_1000_einwohner_2021", data=df);
plt.xlabel("Einwohner in Mio.")
plt.ylabel("Ladestationen pro 1000 Einwohner")
var1 = df['einwohner_in_millionen']
var2 = df['ladestationen_pro_1000_einwohner_2021']
np.corrcoef(var1,var2)
# Out:
# array([[ 1.        , -0.26937178],
#        [-0.26937178,  1.        ]])

# %%
sns.regplot(x="prozentualer_anteil_elektrizitaetsverbrauch_am_gesamtverbrauch", y="ladestationen_pro_1000_einwohner_2021", data=df);
plt.xlabel("Prozentualer Anteil Elektrizitätsverbrauch am Gesamtverbrauch")
plt.ylabel("Ladestationen pro 1000 Einwohner")
var1 = df['prozentualer_anteil_elektrizitaetsverbrauch_am_gesamtverbrauch']
var2 = df['ladestationen_pro_1000_einwohner_2021']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.56908467],
#        [0.56908467, 1.        ]])

# %%
sns.regplot(x="bip_je_einwohner_in_usd", y="pkw_pro_ladepunkt", data=df);
plt.xlabel("BIP pro Einwohner")
plt.ylabel("PKWs pro Ladepunkt")
var1 = df['bip_je_einwohner_in_usd']
var2 = df['pkw_pro_ladepunkt']
np.corrcoef(var1,var2)
# Out:
# array([[ 1.        , -0.65058225],
#        [-0.65058225,  1.        ]])

# %%
sns.regplot(x="km_strassennetz", y="pkw_pro_ladepunkt", data=df);
plt.xlabel("Stassennetz in km")
plt.ylabel("PKWs pro Ladepunkt")
var1 = df['km_strassennetz']
var2 = df['pkw_pro_ladepunkt']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.03586812],
#        [0.03586812, 1.        ]])

# %%
sns.regplot(x="einwohner_in_millionen", y="pkw_pro_ladepunkt", data=df);
plt.xlabel("Einwohner in Mio.")
plt.ylabel("PKWs pro Ladepunkt")
var1 = df['einwohner_in_millionen']
var2 = df['pkw_pro_ladepunkt']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.18783568],
#        [0.18783568, 1.        ]])

# %%
sns.regplot(x="entwicklung_einwohner_seit_2012", y="reifegrad_elektroinfrastruktur_2022", data=df);
plt.xlabel("Entwicklung Einwohner seit 2012")
plt.ylabel("Reifegrad Elektroinfrastruktur")
var1 = df['entwicklung_einwohner_seit_2012']
var2 = df['reifegrad_elektroinfrastruktur_2022']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.76161971],
#        [0.76161971, 1.        ]])

# %%
sns.regplot(x="bip_je_einwohner_in_usd", y="reifegrad_elektroinfrastruktur_2022", data=df);
plt.xlabel("BIP pro Einwohner")
plt.ylabel("Reifegrad Elektroinfrastruktur")
var1 = df['bip_je_einwohner_in_usd']
var2 = df['reifegrad_elektroinfrastruktur_2022']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.68423674],
#        [0.68423674, 1.        ]])

# %%
sns.regplot(x="neuzulassung_elektrofahrzeuge", y="reifegrad_elektroinfrastruktur_2022", data=df);
plt.xlabel("Neuzulassung Elektrofahrzeuge")
plt.ylabel("Reifegrad Elektroinfrastruktur")
var1 = df['neuzulassung_elektrofahrzeuge']
var2 = df['reifegrad_elektroinfrastruktur_2022']
np.corrcoef(var1,var2)
# Out:
# array([[1.        , 0.02106526],
#        [0.02106526, 1.        ]])

# %%
SwissData = df[df['land']=='Schweiz']
SpainData = df[df['land']=='Spanien']
GermanData = df[df['land']=='Deutschland']
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2021", data=SwissData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2020", data=SwissData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2021", data=SpainData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2020", data=SpainData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2021", data=GermanData)
sns.regplot(x="bip_je_einwohner_in_usd", y="ladestationen_pro_1000_einwohner_2020", data=GermanData)
plt.ylabel("Anzahl Ladestationen pro 1000 Einwohner")
plt.xlabel("BIP pro Einwohner in USD")
# Out:
# Text(0.5, 0, 'BIP pro Einwohner in USD')

# %%
sns.displot(df, x="bip_je_einwohner_in_usd")

# %%
LandData = df['land']
ReifegradData = df['reifegrad_elektroinfrastruktur_2022']

plt.figure(figsize=(19,10))
plt.bar(x = LandData, height=ReifegradData, data= df)

plt.title('Reifegrad Elektroinfrastruktur im Vergleich', fontsize = 35)
# Out:
# Text(0.5, 1.0, 'Reifegrad Elektroinfrastruktur im Vergleich')

# %%
df_sorted= df.sort_values('reifegrad_elektroinfrastruktur_2022')

plt.figure(figsize=(19,10))
plt.bar('land', 'reifegrad_elektroinfrastruktur_2022', data= df_sorted)


plt.title('Reifegrad Elektroinfrastruktur im Vergleich', fontsize = 35)
# Out:
# Text(0.5, 1.0, 'Reifegrad Elektroinfrastruktur im Vergleich')

# %%
df_sorted= df.sort_values('ladestationen_pro_1000_einwohner_2020')

plt.figure(figsize=(19,10))
plt.bar('land', 'ladestationen_pro_1000_einwohner_2020', data= df_sorted)


plt.title('Ladestationen pro 1000 Einwohner im Vergleich', fontsize = 35)
# Out:
# Text(0.5, 1.0, 'Ladestationen pro 1000 Einwohner im Vergleich')

# %%
df_sorted= df.sort_values('ladestationen_pro_100km_autobahn')

plt.figure(figsize=(19,10))
plt.bar('land', 'ladestationen_pro_100km_autobahn', data= df_sorted)


plt.title('Ladestationen pro 100 km Autobahn im Vergleich', fontsize = 35)
# Out:
# Text(0.5, 1.0, 'Ladestationen pro 100 km Autobahn im Vergleich')

# %%
df_sorted= df.sort_values('neuzulassung_elektrofahrzeuge')

plt.figure(figsize=(19,10))
plt.bar('land', 'neuzulassung_elektrofahrzeuge', data= df_sorted)


plt.title('Neuzulassung Elektrofahrzeuge im Vergleich', fontsize = 35)
# Out:
# Text(0.5, 1.0, 'Neuzulassung Elektrofahrzeuge im Vergleich')
