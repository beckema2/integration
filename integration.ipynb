# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.set_theme(color_codes=True)

# %%
df = pd.read_csv('datenfinal.csv')
df
# Out:
#            land   einwohner entwicklung_einwohner_seit_2012 flaeche_in_km2  \
# 0       Belgien  11’631’136                           4.33%         30’528
# 1   Deutschland  83’237’124                           3.36%        357’376
# 2      Dänemark   5’873’420                           4.74%         42’924
# 3      Finnland   5’548’241                           2.36%        338’440
# 4    Frankreich  67’842’582                           2.80%        633’187
# 5       Italien  58’983’122                          -0.80%        302’073
# 6   Niederlande  17’590’672                           4.65%         41’540
# 7      Norwegen   5’455’582                           7.77%        385’207
# 8         Polen  37’654’247                          -0.74%        312’679
# 9      Portugal  10’352’042                          -2.05%         92’226
# 10     Schweden  10’452’326                           9.42%        438’574
# 11      Schweiz   8’738’791                           8.76%         41’285
# 12     Slowakei   5’434’712                           0.74%         49’035
# 13      Spanien  47’432’805                           1.18%        505’944
# 14   Tschechien  10’516’707                           1.80%         78’868
# 15       Ungarn   9’689’010                          -2.12%         93’011
# 16   Österreich   8’978’929                           6.24%         83’879
#
#     einwohner_pro_km2 bip_je_einwohner_usd  \
# 0                 381               51’875
# 1                 233               50’795
# 2                 137               67’758
# 3                  16               54’008
# 4                 107               44’853
# 5                 195               35’473
# 6                 423               58’292
# 7                  14               89’090
# 8                 120               17’815
# 9                 112               24’264
# 10                 24               60’029
# 11                212               93’720
# 12                111               21’053
# 13                 94               30’090
# 14                133               26’411
# 15                104               18’968
# 16                107               53’368
#
#    gesamtausgaben_bildung_prozentual_bip gesamtausgaben_bildung_pro_kopf  \
# 0                                  6.40%                           3’320
# 1                                  5.00%                           2’540
# 2                                  7.80%                           5’285
# 3                                  6.30%                           3’403
# 4                                  5.40%                           2’422
# 5                                  4.30%                           1’525
# 6                                  5.40%                           3’148
# 7                                  7.60%                           6’771
# 8                                  4.60%                             819
# 9                                  4.70%                           1’140
# 10                                 7.60%                           4’562
# 11                                 4.90%                           4’592
# 12                                 4.00%                             842
# 13                                 4.20%                           1’264
# 14                                 4.30%                           1’136
# 15                                 4.60%                             873
# 16                                 5.20%                           2’775
#
#    strassennetz_in_km anzahl_registrierter_pkws neuzulassung_plug_hybride  \
# 0               1’763                 5’889’000                    47'761
# 1              13’192                48’249’000                   325'449
# 2               1’354                 2’724’000                    40'478
# 3                 933                 3’633’000                    20'139
# 4              11’660                38’346’000                   141'001
# 5               6’977                39’718’000                    70'472
# 6               2’789                 8’794’000                    31'016
# 7                 580                 2’935’000                    38'166
# 8               1’712                25’114’000                     9'269
# 9               3’065                 5’566’000                    15'660
# 10              2’179                 4’943’000                    77'842
# 11              1’544                 4’658’000                    21'790
# 12                521                 2’440’000                     1'166
# 13             15’722                24’717’000                    43'226
# 14              1’298                 6’049’000                     3'907
# 15              1’774                 3’921’000                     4'236
# 16              1’749                 5’092’000                    14'626
#
#     neuzulassung_elektrofahrzeuge anzahl_ladestationen  \
# 0                             NaN               13’695
# 1                             NaN               59’410
# 2                             NaN                5’752
# 3                             NaN                5’497
# 4                             NaN               37’128
# 5                             NaN               23’543
# 6                             NaN               90’284
# 7                             NaN                7’689
# 8                             NaN                2’811
# 9                             NaN                4’124
# 10                            NaN               25’197
# 11                            NaN                7’200
# 12                            NaN                1’367
# 13                            NaN               10’480
# 14                            NaN                2’189
# 15                            NaN                2’541
# 16                            NaN               13’110
#
#     ladestationen_pro_1000_einwohner_2020  \
# 0                                    0.71
# 1                                    0.53
# 2                                    0.51
# 3                                    0.60
# 4                                    0.67
# 5                                    0.22
# 6                                    3.53
# 7                                    3.40
# 8                                    0.02
# 9                                    0.20
# 10                                   0.92
# 11                                   0.85
# 12                                   0.11
# 13                                   0.16
# 14                                   0.09
# 15                                   0.10
# 16                                   0.91
#
#     ladestationen_pro_1000_einwohner_2021 pkw_pro_ladepunkt  \
# 0                                    1.15               518
# 1                                    0.77             1’014
# 2                                    1.05               727
# 3                                    0.99               951
# 4                                    0.78               718
# 5                                    0.45             2’273
# 6                                    4.81               109
# 7                                    4.50               147
# 8                                    0.08             7’507
# 9                                    0.42             1’596
# 10                                   2.01               353
# 11                                   1.20               575
# 12                                   0.32             1’851
# 13                                   0.31             3’118
# 14                                   0.25             4’576
# 15                                   0.26             1’813
# 16                                   1.92               594
#
#     pro_100km_autobahn  reifegrad_elektroinfrastruktur_2021  \
# 0                   50                                    5
# 1                   73                                    4
# 2                   59                                    4
# 3                  100                                    5
# 4                   48                                    5
# 5                   37                                    4
# 6                  106                                    9
# 7                  780                                    9
# 8                   58                                    2
# 9                   37                                    3
# 10                 125                                    4
# 11                 130                                    5
# 12                   3                                    4
# 13                  21                                    3
# 14                  94                                    3
# 15                  31                                    3
# 16                 115                                    6
#
#     reifegrad_elektroinfrastruktur_2022
# 0                                     6
# 1                                     3
# 2                                     5
# 3                                     6
# 4                                     4
# 5                                     3
# 6                                    10
# 7                                     8
# 8                                     3
# 9                                     2
# 10                                    7
# 11                                    7
# 12                                    4
# 13                                    3
# 14                                    5
# 15                                    4
# 16                                    8

# %%
x = range(95000)

plt.figure(figsize=(15, 15))

sns.scatterplot(x="bip_je_einwohner_usd",y="einwohner", data=df)
x = range(95000)
plt.ylabel("Einwohner / km2")
plt.xlabel("123")
plt.show()

# %%
sns.catplot(x="reifegrad_elektroinfrastruktur_2022", y="land", data=df)
plt.ylabel("Land")
plt.xlabel("Reifegrad Elektroinfrastruktur 2022")
# Out:
# Text(0.5, 12.44444444444443, 'Reifegrad Elektroinfrastruktur 2022')
